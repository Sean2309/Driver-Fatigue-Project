# %% [markdown]
# ### Object Detection using YOLO
#
# Ultralytics Library : https://github.com/ultralytics/ultralytics
#
# YOLOv5 : https://docs.ultralytics.com/models/yolov5/#supported-tasks-and-modes

# %%
from ultralytics import YOLO
import comet_ml
import torch
import os
# import yaml
from ruamel import yaml
import sys

# %%
# Loading the model : YOLOv5
model = YOLO("yolov8n.pt")

model.info()
# Out:
# YOLOv8n summary: 225 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (225, 3157200, 0, 8.8575488)

# %%
# Creating yml file based on cwd

def create_dataset_yml():
    # Init yaml objects
    yaml_obj = yaml.YAML()
    yaml_scalar_str = yaml.scalarstring.DoubleQuotedScalarString
    yaml_comments = yaml.comments.CommentedSeq

    yaml_obj.default_flow_style = None  # Set None for single-line lists

    # Get Base path and resolve it by moving up two levels
    base_path = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))

    # Generate path variables with resolved absolute path
    dataset_path = os.path.join(base_path, "Datasets/Dataset_2/Processed_Images/Images")

    # Create the dictionary with paths generated by os.path.join
    yaml_content = {
        'train': yaml_scalar_str(os.path.join(dataset_path, "train").replace("\\", "/")),
        'val': yaml_scalar_str(os.path.join(dataset_path, "val").replace("\\", "/")),
        'test': yaml_scalar_str(os.path.join(dataset_path, "test").replace("\\", "/")),
        'nc': 2,  # Number of classes
        'names': yaml_comments(["Drowsy", "Non Drowsy"])
    }

    # Set 'names' list to flow style to ensure single-line format
    yaml_content['names'].fa.set_flow_style()

    with open("dataset.yml", "w") as f:
        yaml_obj.dump(yaml_content, f)
    print("Generated dataset.yml with dynamic paths.")

# create_dataset_yml()

# %% [markdown]
# https://www.thinkautonomous.ai/blog/anchor-boxes/

# %% [markdown]
# ## Training YOLOv5 Model
#
# ### Default Parameters
# - `Optimiser` : Stochastic Gradient Descent (SGD)

# %%
# Training the model on preprocessed images
# --batch 16
# %run yolov5/train.py --epochs 50 --data dataset.yml --weights yolov5su.pt
results_output_dir = os.getcwd()
print(results_output_dir)
results = model.train(data="dataset.yml", batch=16, epochs=50, plots=True, project=results_output_dir, name="results")
# Out:
# c:\SUTD\Term 7\CV\Driver-Fatigue-Project\model\yolo
# Ultralytics 8.3.27  Python-3.12.4 torch-2.5.1+cpu CPU (AMD Ryzen 9 5900HX with Radeon Graphics)
# ...
